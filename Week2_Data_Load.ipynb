# %% [markdown]
# <a href="https://colab.research.google.com/github/yjun13/ML_2026_Spring/blob/main/Week2_Data_Load.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls ./drive/MyDrive -la
# Out:
# total 4
# drwx------ 2 root root 4096 Feb 23 07:11 'Colab Notebooks'

# %%
import pandas as pd
pd.read_csv("/content/drive/MyDrive/Colab Notebooks/titanic_train.csv")
titanic_df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/titanic_train.csv")

# %%
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import pandas as pd

path = 'https://github.com/yjun13/ML_2026_Spring/raw/main/Data/'
file = path + 'vehicle_prod.csv'

df = pd.read_csv(file)

# %%
df
# Out:
#   Unnamed: 0   2007   2008   2009   2010   2011
# 0      China   7.71   7.95  11.96  15.84  16.33
# 1         EU  19.02  17.71  15.00  16.70  17.48
# 2         US  10.47   8.45   5.58   7.60   8.40
# 3      Japan  10.87  10.83   7.55   9.09   7.88
# 4      Korea   4.04   3.78   3.45   4.20   4.62
# 5     Mexico   2.01   2.05   1.50   2.25   2.54
